# %%
import os
import io
import sys
import cv2
import numpy as np
from PIL import Image
import tensorflow as tf
from pathlib import Path
import matplotlib.pyplot as plt

# Add the root folder to sys.path
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), "..")))
# Out:
# 2025-03-10 23:00:16.429132: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-03-10 23:00:16.518535: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-03-10 23:00:16.518606: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-03-10 23:00:16.526794: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
from core.metrics import Metrics
from core.models import StegoModel
from core import models_utils as ml_utils
from core.utils import load_image_metadata, save_image_metadata

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # 1. Steguz Data Hiding/Revealing test

# %%
model_path_hide = Path(r'/app/models/hide/steguz/')
model_path_reveal = Path(r'/app/models/reveal/steguz/')
dim_image = 224

# %%
steguz_model = StegoModel(
    model_path_hide=model_path_hide,
    model_path_reveal=model_path_reveal,
    framework="tensorflow",
    objective='both',
    custom_objects={'get_custom_loss':ml_utils.get_steguz_loss},
    post_process_hide_func=lambda raw_stegos: ml_utils.post_process_hide_func_steguz(raw_stegos,
                                                                  scale=dim_image),
    pre_process_reveal_func=lambda stegos_dict: ml_utils.pre_process_reveal_func_steguz(stegos_dict,
                                                                                 scale=dim_image)
)
# Out:
# 2025-03-10 23:00:20.488222: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-03-10 23:00:20.613123: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-03-10 23:00:20.613186: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-03-10 23:00:20.619482: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# ...

# %%
steguz_model.model.summary()
# Out:
# Model: "model_9"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ...
#  input_64 (InputLayer)       [(8, 224, 224, 3)]           0         []
#
#  input_65 (InputLayer)       [(8, 224, 224, 3)]           0         []
#
#  DWT_net (Functional)        (8, 224, 224, 3)             0         ['input_64[0][0]',
#                                                                      'input_65[0][0]']
#
#  tf.reshape_245 (TFOpLambda  (8, 112, 112, 4, 3)          0         ['DWT_net[0][0]']
#  )
#
#  tf.reshape_246 (TFOpLambda  (8, 112, 112, 4, 3)          0         ['DWT_net[1][0]']
#  )
#
#  hide_net (Functional)       (8, 112, 112, 4, 3)          766203    ['tf.reshape_245[0][0]',
#                                                                      'tf.reshape_246[0][0]']
#
# ...
# Total params: 766203 (2.92 MB)
# Trainable params: 766203 (2.92 MB)
# ...

# %% [markdown]
# ### Data hiding testing for one image

# %%
# Uploading images with opencv (BGR, uint8) # images are already in 224x224
cover = cv2.imread(Path(r"/app/data/processed/CFD/CFD_original/AF-204/CFD-AF-204-067-N_original_224_224.png"))
secret = cv2.imread(Path(r'/app/data/secret/base/base_secret.jpg'))
# Convert to RGB
cover = cv2.cvtColor(cover, cv2.COLOR_BGR2RGB)
cover_norm = cover.astype('float32') / 255.0
secret = cv2.cvtColor(secret, cv2.COLOR_BGR2RGB)
secret_norm = secret.astype('float32') / 255.0

# %%
# Set up the figure to display both images
plt.figure(figsize=(10, 5))

# Display cover image
plt.subplot(1, 2, 1)
plt.imshow(cover)
plt.title("Cover Image")
plt.axis("off")

# Display secret image
plt.subplot(1, 2, 2)
plt.imshow(secret)
plt.title("Secret Image")
plt.axis("off")

# Show the images
plt.show()

# %%
cover_list = [cover_norm]
result = steguz_model.hide(cover_list, secret_norm, batch_size=8) # batch size of 8 because the model was trained with a fixed batch number
# Out:
# 2025-03-10 23:00:23.098306: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:454] Loaded cuDNN version 8906
# 2025-03-10 23:00:25.205911: W external/local_tsl/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 6.03GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2025-03-10 23:00:25.458291: W external/local_tsl/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 6.03GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# ...

# %%
# memory usage in GB
steguz_model.gpu_memory_usage()
# Out:
# Values are in GB.
# {'current': 0.012933969497680664, 'peak': 2.684129476547241}

# %%
stego = result["stego_images"][0]
result
# Out:
# {'stego_images': [array([[[239, 239, 243],
#           [242, 244, 239],
#           [240, 243, 246],
#           ...,
#           [244, 245, 239],
#           [237, 239, 245],
#           [242, 244, 237]],
#
#          [[242, 241, 239],
#           [239, 240, 243],
#           [242, 243, 238],
#           ...,
#           [239, 241, 246],
#           [244, 244, 241],
#           [239, 241, 246]],
#
#          [[239, 239, 243],
#           [242, 244, 239],
#           [240, 243, 246],
#           ...,
#           [244, 245, 239],
#           [237, 239, 245],
#           [242, 244, 237]],
#
#          ...,
#
#          [[244, 242, 238],
#           [241, 241, 244],
#           [242, 243, 238],
#           ...,
#           [187, 191, 198],
#           [190, 191, 190],
#           [182, 185, 193]],
#
#          [[240, 239, 242],
#           [243, 243, 239],
#           [238, 243, 246],
#           ...,
#           [188, 190, 184],
#           [184, 186, 194],
# ...

# %%
# Set up the figure with three subplots
plt.figure(figsize=(15, 5))

# Display the cover image
plt.subplot(1, 3, 1)
plt.imshow(cover)
plt.title("Cover Image")
plt.axis("off")

# Display the secret image
plt.subplot(1, 3, 2)
plt.imshow(secret)
plt.title("Secret Image")
plt.axis("off")

# Display the stego image
plt.subplot(1, 3, 3)
plt.imshow(stego)
plt.title("Stego Image")
plt.axis("off")

plt.show()

# %% [markdown]
# ### Compute metrics

# %%
evaluator_hide = Metrics(cover.astype(np.uint8), stego.astype(np.uint8))
evaluator_hide.compute_all()
# Out:
# {'ssim': 0.9239853606175644,
#  'mse': 124.07354113520408,
#  'psnr': 27.19401183431397}

# %%
save_image_metadata(image=Image.fromarray(result['stego_images'][0]),
          output_path = Path('/app/output/test/test_image_hiding.png'),
          metadata = {'min_value':result['min_values'][0],
                      'max_value':result['max_values'][0]})
# Out:
# Image saved at: /app/output/test/test_image_hiding.png with metadata: {'min_value': -0.014966574, 'max_value': 1.0562992}

# %% [markdown]
# ### Data revealing testing for one image

# %%
stego_image, metadata = load_image_metadata(Path('/app/output/test/test_image_hiding.png'),
                              operation='reveal')

# %%
result = {"stego_images": [np.array(stego_image)],
         "min_values":[float(metadata["min_value"])],
         "max_values":[float(metadata["max_value"])]}

# %%
recovered_secrets = steguz_model.reveal(result, batch_size=8) # batch size of 8 because the model was trained with a fixed batch number
# Out:
# GPU memory has been reset.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# 1/1 [==============================] - 1s 842ms/step

# %%
recovered_secrets
# Out:
# {'secret_images': array([[[[0.9397701 , 0.9447003 , 0.96342021],
#           [0.94969499, 0.95343697, 0.97507238],
#           [0.95512015, 0.96424574, 0.98468179],
#           ...,
#           [0.9583295 , 0.96630204, 1.        ],
#           [0.94363558, 0.95738119, 1.        ],
#           [0.9612543 , 0.97221339, 1.        ]],
#
#          [[0.94682539, 0.94793969, 0.97079188],
#           [0.96947706, 0.96810406, 0.98626119],
#           [0.95867002, 0.96477789, 0.98372501],
#           ...,
#           [0.96541917, 0.97023773, 1.        ],
#           [0.96197492, 0.95563722, 1.        ],
#           [0.97296083, 0.97133052, 1.        ]],
#
#          [[0.9397701 , 0.9447003 , 0.96342021],
#           [0.94969499, 0.95343697, 0.97507238],
#           [0.95512015, 0.96424574, 0.98468179],
#           ...,
#           [0.9583295 , 0.96630204, 1.        ],
#           [0.94363558, 0.95738119, 1.        ],
#           [0.9612543 , 0.97221339, 1.        ]],
#
#          ...,
#
# ...

# %%
recovered_image = recovered_secrets['secret_images'][0]

# %%
# Set up the figure with three subplots
plt.figure(figsize=(15, 5))

# Display the cover image
plt.subplot(1, 3, 1)
plt.imshow(stego)
plt.title("Stego Image")
plt.axis("off")

# Display the secret image
plt.subplot(1, 3, 2)
plt.imshow(secret_norm)
plt.title("Secret Image")
plt.axis("off")

# Display the stego image
plt.subplot(1, 3, 3)
plt.imshow(recovered_image)
plt.title("Recovered Image")
plt.axis("off")

plt.show()

# %%
evaluator_reveal = Metrics(secret_norm, recovered_image)
evaluator_reveal.compute_all()
# Out:
# {'ssim': 0.9401023, 'mse': 0.0014289862421276627, 'psnr': 76.58052313320329}

# %%
evaluator_reveal = Metrics((secret_norm*255.).astype(np.uint8), (recovered_image*255.).astype(np.uint8))
evaluator_reveal.compute_all()
# Out:
# {'ssim': 0.9386829093624157,
#  'mse': 99.63432052508503,
#  'psnr': 28.146713974722832}

# %%
save_image_metadata(image=Image.fromarray((recovered_image*255.).astype(np.uint8)),
          output_path = Path('/app/output/test/test_image_revealing.png'))
# Out:
# Image saved at: /app/output/test/test_image_revealing.png with metadata: {}

# %%
steguz_model.gpu_memory_reset() # reset memory
# Out:
# GPU memory has been reset.
